# %% [markdown]
# >## <font color="orange"><b>Introducción</b></font>

# %%
R1 = Region[Disk[{3, 1.5}, 1]];
R2 = Region[Disk[{4, 1.5}, 1]];
R3 = Rectangle[{0, 0}, {7, 3}];
R12 = RegionUnion[R1, R2];
region = RegionUnion[RegionDifference[R3, R12], Disk[{3.5, 1.5}, 0.7]];
words = {13 -> "Álgebra Lineal", 13 -> "T(u + v) = T(u) + T(v)", 13 -> "T(cv) = cT(v)", 13 -> "ax + b = 0",13 -> "Mv = cv", 
    12 -> "Espacios Vectoriales", 12 -> "Transformaciones Lineales", 12 -> "Sistemas de Ecuaciones Lineales",
    11 -> "Eigenvectores", 11 -> "Eigenvalores", 11 -> "Grupo", 11 -> "Campo", 11 -> "Matriz", 11 -> "Vector",
    10 -> "Determinantes", 10 -> "Opreraciones con Matrices", 10 -> "Opreraciones con Determinantes", 10 -> "Traza",
    10 -> "Método de Gauss Jordan", 10 -> "Método Cramer", 10 -> "Dependencia Lineal", 10 -> "Norma",
    10 -> "Grupo", 10 -> "Campo",  13 -> "Vector",
    8 -> "Axiomas de Igualdad", 8 -> "Axiomas de Campo", 8 -> "Axiomas de Grupo", 8 -> "Axiomas de Orden",
    8 -> "Neutro Aditivo", 8 -> "Neutro Multiplicativo", 8 -> "Inverso Aditivo", 8 -> "Inverso Multiplicativo",
    7 -> "Leyes de Conmutación", 7 -> "Leyes Asociativas", 7 -> "Leyes Distributivas", 7 -> "Antisimetría",
    7 -> "Ley Reflexiva", 7 -> "Ley Simétrica", 7 -> "Ley Transitiva"
    10 -> "Números Reales", 10 -> "Números Complejos", 10 -> "Operaciones Binarias", 10 -> "Variables",
    10 -> "Independencia Lineal", 10 -> "Producto Escalar", 10 -> "Producto Vectorial", 9 -> "Combinaciones Lineales",
    9 -> "Rotaciones", 9 -> "Traslaciones", 9 -> "Reflexiones", 9-> "Bases", 9 -> "Ortogonalidad",
    8 -> "Matrices Cuadradas", 8 -> "Matrices Triangulares", 8 -> "Matriz Transpuesta", 8 -> "Matriz Inverza",
    8 -> "Matriz Unitaria", 8 -> "Matrices Semejantes"};
WordCloud[words, region, FontTracking -> "Extended", ImageSize -> 500]
# Out:
# -Graphics-

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>¿Qué es el álgebra lineal?</b>
#
# <b>Sistemas lineales. Ejemplo</b>: <i>Considere el siguiente sistema lineal de ecuaciones:</i>
#
# \begin{equation*}
#     x + y = 3 \\
#     -x + y = -1
# \end{equation*}
#
# <i>Este sistema representa un par de líneas rectas:</i>
#
# </font>
# </div>

# %%
Plot[{y[x] = 3 - x, y[x] = x + 1}, {x, -3, 5}]
# Out:
# -Graphics-

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Preguntas clave:</b>
#
# <ol>
# <li><i>¿El sistema tiene solución?</i></li>
#
# <li><i>¿El sistema tiene una solución aproximada?</i></li>
#
# <li><i>¿El sistema tiene solo una tiene solución?</i></li>
# </ol>
#
# <i>El álgebra lineal esudia los sistemas lineales (ecuaciones).</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Transformaciones geométricas. Ejemplo</b>: <i>Espejo</i>
#
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQDYU4htEL3nyfYMawWYGTb5B2RwnsnH-9tfA&usqp=CAU" width="450" align="left">
#
# </font>
# </div>
#
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Ejemplo</b>: <i>Rotar una figuar</i>
#
# </font>
# </div>

# %%
Graphics[{Green, Rectangle[{0, 0}, {2, 2}],
    Red, Rotate[Rectangle[{3, 0}, {5, 2}], 45 \[Degree]],
    Green, Rectangle[{6.5, 0}, {8.5, 2}],
    Red, Rotate[Rectangle[{6.5, 0}, {8.5, 2}], 45 \[Degree]], Black, Point[{7.5,1}]}]
# Out:
# -Graphics-

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Preguntas clave:</b>
#
# <ol>
# <li><i>¿Se puede encontrar una descripción algebraica de esta transformación?</i></li>
#
# <li><i>¿Hay alguna parte que no haya cambiado por esta transformación?</i></li>
# </ol>
#
# <i>El álgebra lineal estudia las transformaciones lineales.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>¿Matrices?</b>
#
# <b>Definición preliminar</b>: <i>Una matriz es una arreglo rectangular de números en filas y columnas. Por ejemplo</i>
#
# \begin{equation*}
#     A =
#     \begin{pmatrix}
#         2 & 5 \\
#         7 & 3
#     \end{pmatrix}
# \end{equation*}
#
# <i>Los sistemas de ecuaciones lineales y transformaciones lineales se pueden representar utilizando matrices.</i>
#
# <b>Definición preliminar</b>: <i>El determinante de una matriz es un número que está asociado a una matriz. Por ejemplo</i>
#
# \begin{equation*}
#     det(A) =
#     \begin{vmatrix}
#         2 & 5 \\
#         1 & 3
#     \end{vmatrix}
#     = 1
# \end{equation*}
#
# <i>El determinante de una matriz codifica información importante sobre el sistema o transformación correspondiente.</i>
#
# <i>El álgebra lineal es el estudio de los sistemas de ecuaciones lineales y transformaciones lineales mediante matrices y vectores.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Una breve historia del álgebra linea</b>
#
# </font>
# </div>

# %%
TimelinePlot[<|"Gabriel Cramer publica un estudio de Determinantes" -> DateObject[{1750}, "Day"],
    "Karl Friedrich Gauss introdujo la eliminación y el método de mínimos cuadrados" -> DateObject[{1800}, "Day"], 
    "Hermann Grassmann publicó su Teoría de la Extensión" -> DateObject[{1844}, "Day"], 
    "James Sylvester usó el término Matriz para un arreglo de números" -> DateObject[{1848}, "Day"], 
    "Arthur Cayley publica su trabajo sobre la Teoría de Matrices" -> DateObject[{1855}, "Day"],  
    "Benjamin Peirce publicó su Álgebra Lineal Asociativa" -> DateObject[{1872}, "Day"],
    "Giuseppe Peano definió la noción de un Espacio Vectorial abstracto" -> DateObject[{1888}, "Day"]|>,
    PlotStyle -> {Orange}]
# Out:
# -Graphics-

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>¿Por qué estudiar álgebra lineal?</b>
#
# <ol>
# <li><i>Tiene aplicaciones muy amplias en el mundo real.</i></li>
#
# <li><i>Es un curso esencial para ciencias exactas e ingenierías.</i></li>
#
# <li><i>El dominio del álgebra lineal es un logro intelectual importante.</i></li>
# </ol>
#
# </font>
# </div>

# %% [markdown]
# ### <font color="green"><b>Grupos y campos</b></font>

# %% [markdown]
# #### <font color="cyan"><b>Operación binaria</b></font>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición (Operación Binaria)</b>: <i>Una <b>operación binaria</b> es aquella operación matemática, que necesita el operador y dos operandos (argumentos) para que se calcule un valor.</i>
#
# <i>Dados tres conjuntos $A$, $B$ y $C$ una operación binaria (<b>producto</b>), representando la operación por el signo $\color{blue}{\circ}$, es una aplicación que asigna a cada par de valores $a \in A$ y $b \in B$ un solo valor $c \in C$, que podemos representar:</i>
#
#
# \begin{eqnarray*}
# \circ :&A\times B&\longrightarrow &C\\
# &(a,b)&\longmapsto &c
# \end{eqnarray*}
#
# <i>Podemos expresar la operación:</i>
#
# \begin{equation*}
#     a\circ b = c, \quad\circ (a,b) = c, \quad(a,b)\xrightarrow \circ c
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplo</b>: <i>Por ejemplo, el operador de suma $"+"$ de números naturales es un operador binario, porque requiere dos argumentos:</i>
#
# \begin{eqnarray*}
# + :&\mathbb{N}\times \mathbb{N}&\longrightarrow &\mathbb{N}\\
# &(a,b)&\longmapsto &c = a + b
# \end{eqnarray*}
#
# <i>así tenemos por ejemplo:</i>
#
# \begin{equation*}
#     2+5 = 7, \quad+ (2,5) = 7, \quad(2,5)\xrightarrow + 7
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# \begin{equation*}
# \color{blue}{\text{Operación binaria }} \left\{ \begin{array}{ll}
#     \color{green}{\text{ Interna}}& \left\{ \begin{array}{l}
#         \\
#         \color{orange}{A \times A \rightarrow A}\\
#         \\
#         \end{array}
#         \right. \\
#     \color{green}{\text{ Externa}}& \left\{ \begin{array}{l}
#         \color{orange}{B \times A \rightarrow A} \\
#         \\
#         \color{orange}{A \times B \rightarrow B} \\
#         \\
#         \color{orange}{A \times A \rightarrow B} \\
#         \\
#         \color{orange}{A \times B \rightarrow C}
#         \end{array}
#         \right.
#     \end{array}
#     \right. \nonumber
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplo</b>: <i>Suma de vectores en $\mathbb{R}^3$</i>
#
# \begin{eqnarray*}
#     + :&\mathbb{R}^3\times \mathbb{R}^3&\longrightarrow &\mathbb{R}^3\\
#     &\left(\vec{a},\vec{b} \right)&\longmapsto &\vec{c} = \vec{a} + \vec{b}
# \end{eqnarray*}
#
# <i>sean:</i>
#
# \begin{equation*}
# \vec{a} = a_x \hat{\imath} + a_y \hat{\jmath} + a_z \hat{k}\\
# \vec{b} = b_x \hat{\imath} + b_y \hat{\jmath} + b_z \hat{k}
# \end{equation*}
#
# <i>su suma es:</i>
# \begin{equation*}
# \vec{c} = \vec{a} + \vec{b}\\
# \vec{c} =(a_x \hat{\imath} + a_y \hat{\jmath} + a_z \hat{k}) + (b_x \hat{\imath} + b_y \hat{\jmath} + b_z \hat{k})\\
# \vec{c} = (a_x + b_x)\hat{\imath} + (a_y + b_y) \hat{\jmath} + (a_z + b_z) \hat{k}\\
# \vec{c} = c_x \hat{\imath} + c_y \hat{\jmath} + c_z \hat{k}
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplo</b>: <i>Producto de escalar por un vector en $\mathbb{R}^3$:</i>
#
# \begin{eqnarray*}
#     * :&\mathbb{R}\times \mathbb{R}^3&\longrightarrow &\mathbb{R}^3\\
#     &\left(a,\vec{u} \right)&\longmapsto &\vec{v} = a * \vec{u}
# \end{eqnarray*}
#
# <i>sea:</i>
#
# \begin{equation*}
#     \vec{u} = u_x \hat{\imath} + u_y \hat{\jmath} + u_z \hat{k}
# \end{equation*}
#
# <i>entonces:</i>
#
# \begin{equation*}
#     \vec{v} = a * \vec{u}\\
#     \vec{v} =a * (u_x \hat{\imath} + u_y \hat{\jmath} + u_z \hat{k})\\
#     \vec{v} = (a * u_x)\hat{\imath} + (a * u_y) \hat{\jmath} + (a * u_z) \hat{k}\\
#     \vec{v} = v_x \hat{\imath} + v_y \hat{\jmath} + v_z \hat{k}
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# #### <font color="cyan"><b>Grupos</b></font>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición (Grupo)</b>: <i>Un <b>grupo</b> $(G,\circ)$ es un conjunto $G$ en el que se ha definido una <b>operación binaria interna</b> "$\circ$", que satisface los siguientes axiomas:</i>
#
# <ul>
# <li><i><b>Asociatividad:</b></i>
#
# \begin{equation}\label{eq:G_Asoc}
#     \forall\,\ a,b,c\in G:\,\ a\circ (b\circ c) = (a\circ b)\circ c
# \end{equation}
#
# <li><i><b>Elemento neutro:</b></i>
#
# \begin{equation}\label{eq:G_Neut}
#     \exists\,\ u\in G:\,\ u\circ a = a\circ u = a
# \end{equation}
#
# <li><i><b>Elemento inverso:</b></i>
#
# \begin{equation}\label{eq:G_Inv}
#     \forall\,\ a\in G \quad\exists\,\ a^{{-1}}\in G:\,\ a\circ a^{{-1}}=a^{{-1}}\circ a = u
# \end{equation}
#
# <li><i>Se dice que un grupo es <b>abeliano</b> o <b>conmutativo</b> cuando verifica además la <b>propiedad conmutativa:</b></i>
#
# \begin{equation}\label{eq:G_Conm}
#     a\circ b = b\circ a \quad\forall\,\ a,b\in G
# \end{equation}
# </ul>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplos</b>:
#
# <ul>
# <li>$(\mathbb{Z},+)$</li>
#
# <li>$(\mathbb{R},+)$</li>
#
# <li>$(\mathbb{Z}\setminus\{0\},\cdot)$</li>
# </ul>
#
# </font>
# </div>

# %% [markdown]
# #### <font color="cyan"><b>Campos</b></font>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición (Campo)</b>: <i>Un <b>campo</b> $F$ es un conjunto en el cual se definen dos operaciones $+$ y $\cdot$ (llamadas, respectivamente, adición y multiplicación) de modo que para cualquier par de elementos $a, b$ en $F$ existen elementos únicos $a + b$ y $a \cdot b$ en $F$ tales que se cumplen las siguientes condiciones para todos los elementos $a, b, c$ en $F$:</i>
#
# <ul>
# <li><i><b>Conmutatividad de la adición y la multiplicación.</b></i>
#
# \begin{equation}\label{eq:F_Conm}
#     a + b = b + a \quad\text{y} \quad\ a \cdot b = b \cdot a
# \end{equation}
#
# <li><i><b>Asociatividad de la adición y la multiplicación.</b></i>
#
# \begin{equation}\label{eq:F_Asoc}
#     (a + b) + c = a + (b + c) \quad\text{y} \quad\ (a \cdot b) \cdot c = a \cdot (b \cdot c)
# \end{equation}
#
# <li><i><b>Existencia de elementos identidad para la adición y la multiplicación.</b> Existen elementos distintos de $0$ y $1$ en $F$ tales que:</i></li>
#
# \begin{equation}\label{eq:F_Iden}
#     0 + a = a \quad\text{y} \quad\ 1 \cdot a = a
# \end{equation}
#
# <li><i><b>Existencia de inversos para la adición y la multiplicación.</b> Para cada elemento $a$ en $F$ y cada elemento no nulo $b$ en $F$ existen elementos $c$ y $d$ en $F$ tales que:</i>
#
# \begin{equation}\label{eq:F_Inv}
#     a + c = 0 \quad\text{y} \quad\ b \cdot d = 1
# \end{equation}
#
# \begin{equation*}
#     a + (-a) = 0 \quad\text{y} \quad\ b \cdot b^{-1} = b \cdot \frac{1}{b} = \frac{b}{b} = 1
# \end{equation*}
#
# <li><i><b>Distributividad de la multiplicación sobre la adición:</b></i>
#
# \begin{equation}\label{eq:F_Dist}
#     a \cdot (b + c) = a \cdot b + a \cdot c
# \end{equation}
# </ul>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplos</b>:
#
# <ul>
# <li>$\mathbb{Z}$
#
# <li>$\mathbb{R}$
#
# <li>$\mathbb{C}$
# </ul>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color="green" face="Ginebra">
#
# <b>Teorema</b>: <i>Sean $a$ y $b$ elementos cualesquiera de un campo, entonces</i>
#
# <ol>
# <li>$a \cdot 0 = 0$
#
# <li>$(-a)\cdot b = a \cdot (-b) = -(a \cdot b)$
#
# <li>$(-a)\cdot (-b) = a \cdot b$
# </ol>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# <b>Nota</b>: <i>Con los axiomas de campo y sus propiedades, podemos resolver diversos tipos de ecuaciones.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplo</b>: <i>Comencemos con la forma general de una ecuación lineal $ax + b = 0$, $a, b\in\mathbb{R},\, a \neq 0$, que se resuelve despejando $x$</i>
#
# \begin{eqnarray*}
# 	ax + b &=& 0 \\
# 	(ax + b) \color{blue}{+ (-b)} &=& 0 \color{blue}{+ (-b)} &\quad\text{Sumamos el inverso aditivo de $b$} \\
# 	ax \color{blue}{+ \big(b + (-b)\big)} &=& -b &\quad\text{Asociatividad de la suma y neutro aditivo} \\
# 	ax \color{blue}{+ 0} &=& -b &\quad\text{Propiedad del inverso aditivo} \\
# 	ax &=& -b &\quad\text{Propiedad del neutro aditivo} \\
# 	\color{blue}{\frac{1}{a}}(ax) &=&  \color{blue}{\frac{1}{a}}(-b) &\quad\text{Multiplicamos por el inverso multiplicativo de $a$} \\
# 	\color{blue}{\left(\frac{1}{a}a\right)}x &=&  \color{blue}{-\frac{1}{a}}b &\quad\text{Asociatividad del producto y propiedad de los inversos aditivos} \\
# 	\color{blue}{1}x &=&  -\frac{b}{a} &\quad\text{Propiedad del inverso del producto} \\
# 	x &=& -\frac{b}{a} &\quad\text{Propiedad del neutro multiplicativo}
# \end{eqnarray*}
#
# <i>Para resolver cualquier ecuación lineal, se procede de manera similar.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplo</b>: <i>En el caso de una ecuación cuadrática $ax^2 + bx + c = 0$, $a, b, c\in\mathbb{R},\, a \neq 0$, recordemos como se resuelve</i>
#
# <small>
# \begin{eqnarray*}
# 	ax^2 + bx + c &=& 0 \\
# 	\color{blue}{a}\left(x^2 + \frac{b}{a}x + \frac{c}{a} \right) &=& \color{blue}{a}0 &\,\text{Factorizamos $a$} \\
# 	x^2 + \frac{b}{a}x + \frac{c}{a} &=& 0 &\,\text{Cancelamos $a$} \\
# 	\left(x^2 + \frac{b}{a}x\right) + \frac{c}{a} &=& 0 &\,\text{Asociamos en la suma} \\
# 	\left(x^2 + \frac{b}{a}x \color{blue}{+\frac{b^2}{4a^2}}\right) \color{blue}{-\frac{b^2}{4a^2}} + \frac{c}{a} &=& 0 &\,\text{Sumamos y restamos $\frac{b^2}{4a^2}$ para completar un cuadrado perfecto} \\
# 	\left(x + \frac{b}{2a}\right)^2 &=& \frac{b^2}{4a^2} - \frac{c}{a} &\,\text{Despejamos $\left(x + \frac{b}{2a}\right)^2$} \\
# 	\left(x + \frac{b}{2a}\right)^2 &=& \frac{b^2\color{blue}{a} - c\color{blue}{4a^2}}{4a^2 a} &\,\text{Sumamos las fracciones} \\
# 	x + \frac{b}{2a} &=& \pm \sqrt{\frac{b^2 - 4ac}{2a}} &\,\text{Sacamos raíz a ambos miembros de la ecuación} \\
# 	x &=& -\frac{b \pm \sqrt{b^2 - 4ac}}{2a} &\,\text{Despejamos $x$ y sacamos común denominador} \\
# \end{eqnarray*}
# </small>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# <b>Nota</b>: <i>La operaciones con fracciones están justificadas con los axiomas de campo.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejercicio</b>: <i>Sea $F$ un conjunto que contiene exactamente dos elementos, $0$ y $1$. Se define una adición y multiplicación, como se muestra en las tablas:</i>
#
# \begin{equation*}
#     \begin{array}{c | c c}
#         + & 0 & 1 \\ \hline
#         0 & 0 & 1 \\
#         1 & 1 & 0
#     \end{array}
#     \qquad\
#     \begin{array}{c | c c}
#         \cdot & 0 & 1 \\ \hline
#         0 & 0 & 0 \\
#         1 & 0 & 1
#     \end{array}
# \end{equation*}
#
# <i><b>a)</b> Verificar que el conjunto $F$, con estas dos operaciones, es un campo.</i>
#
# <i><b>b)</b> Dar un ejemplo de aplicación del campo $F$ en la vida real.</i>
#
# <i><b>Nota</b>: Este campo se le conoce como $\mathbb{Z}_2$.</i>
#
# </font>
# </div>

# %% [markdown]
# ### <font color="green"><b>Sistemas de Ecuaciones Lineales</b></font>

# %% [markdown]
# #### <font color="cyan"><b>Definiciones</b></font>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición (Ecuación)</b>: <i>Una <b>ecuación</b> en $\mathbb{R}$, es una proposición matemática, donde están involucradas las operaciones definidas en $\mathbb{R}$ y que afirma que dos expresiones algebraicas son iguales (las dos expresiones se llaman miembro).</i>
#
# <i><b>Resolver la ecuación</b> es encontrar el conjunto solución de la ecuación, es decir, donde la proposicion se cumple. A los valores en $\mathbb{R}$ que hacen verdadera la ecuación, se les llama soluciones de la ecuación.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición (Ecuación)</b>: <i>Una <b>ecuación lineal</b> es una formulación matemática cuya representación gráfica proporciona como resultado una línea recta, es decir, es una ecuación de primer grado.</i>
#
# <i>Una <b>sistema de ecuaciones lineales</b> (o <b>sistema lineal de ecuaciones</b> o simplemente <b>sistema lineal</b>), es un conjunto de ecuaciones lineales (es decir, un sistema de ecuaciones en donde cada ecuación es de primer grado).</i>
#
# </font>
# </div>

# %% [markdown]
# #### <font color="cyan"><b>Método de eliminación o reducción</b></font>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# <b>Nota</b>: <i>Trabajaremos en el campo de los números reales, $\mathbb{R}$.</i>
#
# <i>Se considera el problema de encontrar $n$ escalares (elementos de $\mathbb{R}$) $x_1, \dots, x_n$, que satisfagan las condiciones</i>
#
# \begin{equation}\label{eq:sit_ecu_lin}
# 	\begin{matrix}
# 		a_{11}x_1 &+\,\cdots\,+& a_{1n}x_n & = & b_1 \\
# 		\vdots & & \vdots & = & \vdots \\
# 		a_{m1}x_1 &+\,\cdots\,+& a_{mn}x_n & = & b_m
# 	\end{matrix}
# \end{equation}
#
# <i>donde $b_1, \dots, b_n$ y $a_{ij}$ son elementos de $\mathbb{R}$, y se le llama <b>sistema de $m$ ecuaciones lineales con $n$ incógnitas</b>. El número $n$ se conoce como el número de <b>incógnitas</b> y $m$ es el número de <b>ecuaciones</b>. Toda $n-$tupla $(x_1, \dots, x_n)$ de elementos de $\mathbb{R}$ que satisface cada una de las ecuaciones de \ref{eq:sit_ecu_lin}) se le llama <b>solución</b> del sistema. Si $b_1 = b_2 = \cdots = b_m = 0$ se dice que el sistema es <b>homogéneo</b>, o que cada una de las ecuaciones es homogénea.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplo</b>: <i>Resolver el siguiente sistema de ecuaciones lineales</i>
#
# \begin{eqnarray*}
# 	2x & + & 3y & = & 12 \\
# 	x & - & y & = & 1
# \end{eqnarray*}
#
# <b>Solución</b>: <i>Tal vez, la técnica fundamental para encontrar las soluciones de un sistema de ecuaciones lineales, es la técnica de eliminación.</i>
#
# <i>Si sumamos ($-2$) veces la segunda ecuación a la primera, se obtiene</i>
#
# \begin{equation*}
# 	5y = 10
# \end{equation*}
#
# <i>De donde obtenemos que $y = 2$. Ahora, si sumamos $3$ veces la segunda ecuación a la primera, se obtiene</i>
#
# \begin{equation*}
# 	5x = 15
# \end{equation*}
#
# <i>De donde obtenemos que $x = 3$. Entonces la solución de este sistema es la dupla $(3, 2)$.</i>
#
# <b>Conclusión</b>: <i>Se ha encontrado la solución del sistema «eliminando incógnitas», esto es, multiplicando las ecuaciones por escalares y sumándolas luego para producir ecuaciones en las cuales algunas de las variables no están presentes.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# <i>Desearíamos formalizar ligeramente este proceso de manera que se pueda entender por qué opera y para así poder llevar a cabo los cálculos necesarios para resolver un sistema de manera sistemática.</i>
#
# </font>
# </div>

# %% [markdown]
# <i>Estaremos trabajando con <b>Wolfram Language</b>. En Wolfram el comando (o función) que nos permite resolver una ecuación o sitema de ecuaciones es: <b>Solve</b>, y su estructura es</i>
#
# > $Solve[ecuación, variable],\qquad\text{en el caso de una sola ecuación}$
#
# > $Solve[\{eq_1, \dots, eq_n\}, \{var_1, \dots, var_m\}],\qquad\text{en el caso de un sistema de } n \text{ ecuaciones con } m \text{ incognitas}$

# %%
(*Escribimos nusteras ecuaciones*)
eq1 = 2*x + 3*y == 12;
eq2 = x - y == 1;
(*Resolvemos el sitema de ecuaciones con el comando Solve*)
Solve[{eq1, eq2}, {x, y}]
# Out:
# {{x -> 3, y -> 2}}

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <i>Para el sistema general (\ref{eq:sit_ecu_lin}), suponga que seleccionamos $m$ escalares $c_1, \dots, c_m$, que se multiplica por la $i-$ésima ecuación por $c_i$ y luego se suma, es decir,</i>
#
# \begin{equation*}
# 	\begin{matrix}
# 		c_1\big(a_{11}x_1 &+\,\cdots\,+& a_{1n}x_n\big) & = & c_1 b_1 \\
# 		\vdots & & \vdots & = & \vdots \\
# 		c_m\big(a_{m1}x_1 &+\,\cdots\,+& a_{mn}x_n\big) & = & c_m b_m
# 	\end{matrix}
# \end{equation*}
#
# <i>Sumando y agrupando tenemos</i>
#
# \begin{equation*}
# 	\big(c_1 a_{11} + \cdots + c_m a_{m1}\big)x_1 + \cdots + \big(c_1 a_{1n} + \cdots + c_m a_{mn}\big)x_m
# 	= c_1 b_1 + \cdots + c_m b_m.
# \end{equation*}
#
# <i>Esta última ecuación se le llama <b>combinación lineal</b> de las ecuaciones \ref{eq:sit_ecu_lin}). Observe que, cualquier solución del sistema de ecuaciones \ref{eq:sit_ecu_lin}) será también solución de esta nueva ecuación. Esta es la idea fundamental del proceso de eliminación.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <i>Si se tiene otro sistema de ecuaciones lineales</i>
#
# \begin{equation}\label{eq:sit_ecu_lin2}
# 	\begin{matrix}
# 		\alpha_{11}x_1 &+\,\cdots\,+& \alpha_{1n}x_n & = & \beta_1 \\
# 		\vdots & & \vdots & = & \vdots \\
# 		\alpha_{k1}x_1 &+\,\cdots\,+& \alpha_{kn}x_n & = & \beta_k
# 	\end{matrix}
# \end{equation}
#
# <i>en que cada una de las $K$ ecuaciones sea combinación lineal de las ecuaciones de (\ref{eq:sit_ecu_lin}), entonces toda solución de (\ref{eq:sit_ecu_lin}) es solución de este nuevo sistema. Evidentemente puede suceder que algunas soluciones de (\ref{eq:sit_ecu_lin2}) no sean soluciones de (\ref{eq:sit_ecu_lin}). Esto, claro está, no sucede si cada ecuación en el sistema original es combinación lineal de las ecuaciones en el nuevo sistema. Se dirá que dos sistemas de ecuaciones lineales son <b>equivalentes</b> si cada ecuación de cada sistema es combinación lineal de las ecuaciones del otro sistema.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color="green" face="Ginebra">
#
# <b>Teorema</b>: <i>Sistemas equivalentes de ecuaciones lineales tienen exactamente las mismas soluciones</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplo</b>: <i>Halle al menos una solución no trivial para el siguiente sistema de ecuaciones lineales.</i>
#
# \begin{eqnarray*}
# 	3x + y + z &=& 0\\
# 	x + y + z &=& 0
# \end{eqnarray*}
#
# <b>Solución</b>: <i>Aplicaremos el método de eliminación: Primero sumamos $(-3)$ veces la segunda ecuación a la primera, entonces tenemos</i>
#
# \begin{equation*}
# 	-2y - 2z = 0,
# \end{equation*}
#
# <i>esto implica que $y = -z$, sustituimos este resultado en cualquiera de las dos ecuaciones, lo haremos en la segunda, entonces</i>
#
# \begin{equation*}
# 	x + y + (-y) = 0 \quad\ x = 0.
# \end{equation*}
#
# <i>Por lo tanto cualquier terna de la forma $(0, a, -a)$ es solución de este sistema de ecuaciones lineales.</i>
#
# <b>Ejercicio</b>: <i>Halle al menos una solución no trivial para el siguiente sistema de ecuaciones lineales.</i>
#
# \begin{eqnarray*}
# 	2x - 3y + 4z &=& 0\\
# 	3x + y + z &=& 0
# \end{eqnarray*}
#
# </font>
# </div>

# %% [markdown]
# ><i>Comprobamos con Wolfram Language</i>

# %%
eq1 = 3 x + y + z == 0;
eq2 = x + y + z == 0;
Solve[{eq1, eq2}, {x, y}]
# Out:
# {{x -> 0, y -> -z}}

# %% [markdown]
# ### <font color="green"><b>Vectores</b></font>

# %% [markdown]
# #### <font color="cyan"><b>Definición de Vector en $\mathbb{R}^n$</b></font>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# <i>Un  umero $(x)$ puede se representado por un punto sobre una recta, una vez que se ha escogido una unidad de longitud</i>
#
# <i>Se puede usas una dupla de números $(x, y)$ para representar un punto en el plano</i>
#
# <i>De forma similar, se puede utilizar una terna de números $(x, y, z)$ para representar un punto en el espacio, podríamos utilizar también $(x_1, x_2, x_3)$</i>
#
# <i>La recta se podría llamar espacio de dimensión $1$, el plano espacio de dimensión $2$, así entonces una terna esta en el espacio de dimensión $3$. Aunque no podamos dibujar un diagrama, nada nos impide considerar una cuádrupla de números $(x_1, x_2, x_3, x_4)$ y afirmar que ésta en un espacio de dimensión $4$, una quíntupla un punto en el espacio de $5$ dimensiones, ...</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición</b>: <i> Un <b>punto en el espacio de $n$-dimensiones</b> es una $n-$tupla</i>
#
# \begin{equation*}
# 	(x_1, x_2, \dots, x_n),
# \end{equation*}
#
# <i>con $n$ un entero positivo. Denotaremos con un $X$ mayúscula dicha $n-$tupla y las con las letras minúsculas representaremos los números. A los números $x_1, x_2, \dots, x_n$, los llamaremos <b>coordenadas</b> del punto $X$. Denotaremos el espacio de $n$-dimensiones con $\mathbb{R}^n$.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# <i>A estas $n-$tuplas las llamaremos <b>vectores</b>, que van del origen (el punto cuyas todas entradas son ceros) al punto indicado por la $n-$tupla.</i>
#
# ><b>¿Para que sirven los vectores?</b>
#
# <i>¿Donde puedo ocuparlos?</i>
#
# <i>¿Como puedo ocuparlos?</i>
#
# <i>Entonces necesitamos definir las propiedades de los vectores, así como las operaciones que podemos realizar con los vectores.</i>
#
# </font>
# </div>

# %% [markdown]
# #### <font color="cyan"><b>Operaciones con Vectores en $\mathbb{R}^n$</b></font>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición (Suma de Vectores)</b>: <i>Si $X$ y $Y$ son dos vectores en $\mathbb{R}^n$,</i>
#
# \begin{equation*}
# 	X = (x_1, x_2, \dots, x_n) \qquad\text{y}\qquad\ Y = (y_1, y_2, \dots, y_n)
# \end{equation*}
#
# <i>entonces definimos $X + Y$ como el punto cuyas coordenadas son.</i>
#
# \begin{equation*}
# 	X + Y = (x_1 + y_1, x_2 + y_2, \dots, x_n + y_n).
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplo</b>: <i>Sean $X = (1, -3, 4)$ y $Y = (3, 5, -2)$, obtener $X + Y$.</i>
#
# <b>Solución</b>: <i>De acuerdo a la definición anterior, tenemos $X + Y = \big(1 + 3, -3 + 5, 4 + (-2)\big) = (4, 2 , 2)$.</i>
#
# <i>Apliquemos la tecnologia para realzar est cálculo (unilizaremos [Wolfram Alpha](https://www.wolframalpha.com/examples/mathematics/linear-algebra/vectors))</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color="green" face="Ginebra">
#
# <b>Propiedades</b>: <i>Sean $X, Y, Z \in\mathbb{R}^n$</i>
#
# <ol>
# <li>$X + Y = Y + X$
#
# <li>$(X + Y) + Z = X + (Y + Z)$
#
# <li><i>Supuniendo que</i>
# \begin{equation*}
# 	O = (0, 0, \dots, 0)
# \end{equation*}
# <i>el el punto cuyas cordenadas son todas cero $0$, entonces</i>
# \begin{equation*}
# 	O + X = X + O = X
# \end{equation*}
# <i>para toda $A$.</i>
#
# <li><i>Sea $X = (x_1, x_2, \dots, x_n)$ y sea $-X = (-x_1, -x_2, \dots, -x_n)$. Entonces</i>
# \begin{equation*}
# 	X + (-X) = X - X = O.
# \end{equation*}
# </ol>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición (Multiplicación de un Vectores por un Escalar)</b>: <i>Sea un vector cualquiera $X$ de dimensión $n$, y sea $c$ cualquier número ($c\in\mathbb{R}$), definimos $cX$ como el punto cuyas coordenadas son</i>
#
# \begin{equation*}
# 	cX = (cx_1, cx_2, \dots,c x_n).
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color="green" face="Ginebra">
#
# <b>Propiedades</b>:  <i>Sean $X, Y \in\mathbb{R}^n$ y $c \in\mathbb{R}$</i>
#
# <ol>
# <li>$c(X + Y) = cX + cY$
#
# <li><i>Si $c_1, c_2 \in\mathbb{R}$, entonces</i>
# \begin{equation*}
# 	(c_1 + c_2)X = c_1 X + C-2 X \qquad\text{y}\qquad\ (c_1 c_2)X = c_1 (c_2 X).
# \end{equation*}
# </ol>
#
# <i>Note que tambien se cumple</i>
# \begin{equation*}
# 	(-1)X = -X.
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejercicio</b>: <i>Describa geométricamente que representa el producto de un escalar por un vector.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición (Vectores Anclados)</b>: <i>Podríamos decir que un vector esta anclado en el origen, y este se encuentra completamente determinado por su punto final (el punto identificado con la $n-$tupla). Entonces un vector anclado en un punto $P_1$ seria aquel que comienza en $P$ y termina en otro punto digamos $Q$, se denota por $\overrightarrow{PQ}$.</i>
#
# <i>Se dice que dos vectores anclados $\overrightarrow{P_1Q_1}$ y $\overrightarrow{P_2Q_2}$ son <b>paralelos</b> si existe un escalar $c \neq 0$ tal que $Q_1 - P_1 = c(Q_2 - P_2)$. Se dice que tienen la misma <b>dirección</b> si existe un escalar $c > 0$ tal que $Q_1 - P_1 = c(Q_2 - P_2)$ y se dice que tienen <b>direcciones opuestas</b> si existe un escalar $c < 0$ tal que $Q_1 - P_1 = c(Q_2 - P_2)$.</i>
#
# <i>¿Como saber si son perpendiculares?</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# <b>Nota</b>: <i>Cualquier definición enunciada para $n-$tuplas (vectores) se puede aplicar a los vectores anclados.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición (Producto Interior)</b>: <i>Sean $X = (x_1, x_2, \dots, x_n) \,\text{ y }\,\ Y = (y_1, y_2, \dots, y_n)\in\mathbb{R}^n$ dos vectores. Definimos su <b>producto interior</b> (o <b>producto escalar</b> o <b>producto punto</b>) $X \cdot Y$ como sigue</i>
#
# \begin{equation*}
# X \cdot Y = \sum_{i=1}^{n} x_i y_i = x_1 y_1 + x_2 y_2 + \cdots + x_n y_n
# \end{equation*}
#
# <i>Debe notar que este producto es un número</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color="green" face="Ginebra">
#
# <b>Propiedades</b>: <i>Sean $X, Y, Z \in\mathbb{R}^n$ y $c \in \mathbb{R}$, entonces</i>
#
# <ol>
# <li>$X \cdot Y = Y \cdot X$
#
# <li>$X \cdot (Y + Z) = X \cdot Y + X \cdot Z = (Y + Z) \cdot X$
#
# <li>$c(X) \cdot Y = c(X \cdot Y) \qquad\text{y}\qquad\  X \cdot (cY) = c(X \cdot Y)$
#
# <li><i>Sea $O = (0, 0, \dots, 0)$ el vecotr nulo en $\mathbb{R}^n$, entonces</i>
# \begin{equation*}
#     \text{Si } X = O, \quad\text{etonces}\quad\ X \cdot X = 0. \\
#     \text{Si } X \neq O, \quad\text{etonces}\quad\ X \cdot X > 0.
# \end{equation*}
#
# </ol>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# <b>Nota</b>: <i>Se suele utilizar la notación $X^2 = X \cdot X$. Éste es el único caso en el que nos permitimos tal notación, note que $X^3$ no tiene significado alguno.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición</b>: <i>Decimos que dos vectores son <b>perpendiculares</b> (u <b>ortogonales</b>), si $X \cdot Y = 0$</i>
#
# <b>Observación</b>: <i>Si $Y$ es perpendicular a $X$, entonces $cY$ tambien lo es, debido a que $X \cdot (cY) = c (X \cdot Y) = 0$.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición</b>: <i>Definimos la <b>norma</b> (o <b>magnitud</b>) de un vecotr $X$ al número</i>
# \begin{equation*}
#     \|X\| = \sqrt{X \cdot X}
# \end{equation*}
#
# <i>Definimos la <b>distancia</b> entre $X$ y $Y$ como</i>
# \begin{equation*}
#     \|X - Y\| = \sqrt{(X - Y) \cdot (X - Y)}
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <font color="green" face="Ginebra">
#
# <b>Teorema</b>: <i>sea $c\in\mathbb{R}$, entonces</i>
#
# \begin{equation*}
#     \|cX\| = |c| \|X\|
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición</b>: <i>Decimos que un vector $E$ es <b>unitario</b> si $\|E\| = 1$. Dado cualquier vector $X \in\mathbb{R}^n$, sea $x = \|X\|$. Si $x \neq 0$, entonces</i>
# \begin{equation*}
#     \frac{1}{x}X = \frac{1}{\|X\|}X
# \end{equation*}
# <i>es un vecor unitario en la dirección de $X$</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <font color="blue" face="Ginebra">
#
# <b>Definición</b>: <i>La <b>componente</b> de un vecotr $Y$ a lo largo del vector $X$ es</i>
# \begin{equation*}
#     c = \frac{X \cdot Y}{X \cdot X}
# \end{equation*}
#
# <i>La <b>proyección</b> del vecotr $Y$ a lo largo del vector $X$ es</i>
# \begin{equation*}
#     Y_X = cX = \big(X \cdot Y\big)\frac{X}{\|X\|^2}
# \end{equation*}
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color="grey" face="Ginebra">
#
# <b>Nota</b>: <i>En algunos tratados sobre vectores, se considera la relación</i>
#
# \begin{equation*}
# 	X \cdot Y = \|X\| \|Y\| \cos(\theta)
# \end{equation*}
# <i>donde $\theta$ es el angulo entre los dos vectores. Esta definición tiene algunas desventajas.</i>
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <font color="purple" face="Ginebra">
#
# <b>Ejemplo</b>: <i>Sean $X = (2, -2, 5)$ y $Y = (-1, 7, 3)$ obtener:</i>
#
# <b>a)</b> <i>$X \cdot Y$,¿Los vectores $X$ y $Y$ son perpendiculares?</i>
#
# <b>b)</b> <i>La distancia entre los vectores $X$ y $Y$. </i>
#
# <b>c)</b> <i>La proyección del vector $Y$ a lo largo de $X$. </i>
#
# <b>Solución</b>:
#
# <b>a)</b> <i>Aplicando la definición tenemos $X \cdot Y = (2)(-1) + (-2)(7) + (5)(3) = -1$, debido a que $X \cdot Y \neq 0$ entonces $X$ y $Y$ no son perpendiculares</i>
#
# <b>b)</b> <i>Primero obtenemos $X - Y = \big(2 - (-1), -2 - 7, 5 - 3\big) = \big(3, -9, 2\big)$, ahora obetenmos $(X - Y) \cdot (X- Y) = (3)^2 + (-9)^2 + (2)^2 = 94$, entonces $\|X - Y\| = \sqrt{94}$.</i>
#
# <b>c)</b> <i>Primero obtenemos la norma $\|X\| = (2)^2 + (-2)^2 + (5)^2 = \sqrt{33}$, y el producto escalar $X \cdot Y = -1$. Por lo tanto la proyeccion esta dada por $Y_X = \frac{-1}{33}(2, -2, 5) = \left(\frac{-3}{33}, \frac{2}{33}, \frac{-5}{33}\right)$</i>
#
# <i>Utilizando [Wolfram Alpha](https://www.wolframalpha.com/examples/mathematics/linear-algebra/vectors))</i>
#
# </font>
# </div>

# %% [markdown]
# >En Wolfram, podremos realizar operaciones con vectores, veamos algunas operaciones resolviendo el ejemplo anterior.

# %%
(*Definiendo vectores*)
v1 = {2, -2, 5};
v2 = {-1, 7, 3};
(*Ooperaciones básicas con vectores*)
rest = v1 - v2       (*Suma o resta de vectores*)
tresv1 = 3 v1        (*El producto por escalar se indica con un "espacio" o utilizando el simbolo *.*)
dist2 = rest.rest    (*Producto punto*)
dist = Norm[rest]    (*Norma de un vector*)
Norm[v1]
Projection[v2, v1]   (*Proyección de un vector sobre otro vector*)
# Out:
# {3, -9, 2}
# {6, -6, 15}
# 94
# Sqrt[94]
# Sqrt[33]
#    2    2     5
# {-(--), --, -(--)}
#    33   33    33
